# %%
import pandas as pd
# load in the flights csv
df = pd.read_csv('flights.txt', sep="|")
print(df)
# Out:
#          TRANSACTIONID  FLIGHTDATE AIRLINECODE  \
# 0             54548800    20020101          WN
# 1             55872300    20020101          CO
# 2             54388800    20020101          WN
# 3             54486500    20020101          WN
# 4             55878700    20020103          CO
# ...                ...         ...         ...
# 1191800      126750200    20130106          EV
# 1191801      127294500    20130106          DL
# 1191802      127294900    20130106          DL
# 1191803      126594900    20130106          EV
# 1191804      126620300    20130106          EV
#
#                             AIRLINENAME TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 0            Southwest Airlines Co.: WN  N103@@       1425               ABQ
# 1        Continental Air Lines Inc.: CO  N83872        150               ABQ
# 2            Southwest Airlines Co.: WN  N334@@        249               ABQ
# 3            Southwest Airlines Co.: WN  N699@@        902               ABQ
# 4        Continental Air Lines Inc.: CO  N58606        234               ABQ
# ...                                 ...     ...        ...               ...
# 1191800    ExpressJet Airlines Inc.: EV  N683BR       5272               ATL
# 1191801        Delta Air Lines Inc.: DL  N949DL       1711               ATL
# 1191802        Delta Air Lines Inc.: DL  N907DE       1810               ATL
# 1191803    ExpressJet Airlines Inc.: EV  N855AS       5208               ATL
# 1191804    ExpressJet Airlines Inc.: EV  N138EV       5549               ATL
#
#                                            ORIGAIRPORTNAME ORIGINCITYNAME  \
# 0         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 2         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 3         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 4         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# ...                                                    ...            ...
# 1191800  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191801  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191802  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191803  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191804  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
#
#         ORIGINSTATE  ... WHEELSON TAXIIN CRSARRTIME ARRTIME ARRDELAY  \
# 0                NM  ...   1648.0    4.0       1655  1652.0     -3.0
# 1                NM  ...   1419.0   16.0       1426  1435.0      9.0
# 2                NM  ...   1618.0    2.0       1500  1620.0     80.0
# 3                NM  ...   1947.0    1.0       1950  1948.0     -2.0
# 4                NM  ...   1742.0    5.0       1750  1747.0     -3.0
# ...             ...  ...      ...    ...        ...     ...      ...
# 1191800          GA  ...   1500.0    3.0       1523  1503.0    -20.0
# 1191801          GA  ...   2307.0   10.0       2321  2317.0     -4.0
# 1191802          GA  ...   1728.0    9.0       1750  1737.0    -13.0
# 1191803          GA  ...   1651.0    4.0       1658  1655.0     -3.0
# 1191804          GA  ...   1611.0    4.0       1609  1615.0      6.0
#
#         CRSELAPSEDTIME  ACTUALELAPSEDTIME  CANCELLED  DIVERTED   DISTANCE
# 0                 90.0               87.0          F     False  580 miles
# 1                116.0              119.0      False         F  744 miles
# 2                105.0              102.0          F     False  718 miles
# 3                 85.0               83.0          0         0  487 miles
# 4                115.0              114.0          F     False  744 miles
# ...                ...                ...        ...       ...        ...
# 1191800          146.0              135.0          0         0  721 miles
# 1191801          151.0              150.0      False         F  731 miles
# 1191802          153.0              140.0          F     False  731 miles
# 1191803          102.0              101.0      False         F  508 miles
# 1191804           77.0               77.0      False     False  306 miles
#
# [1191805 rows x 31 columns]

# %%
# - what’s wrong with the `DIVERTED` column? It looks right at a glance, but what is the type of each entry? Look up how to cast a column to a different type in pandas
print(df['DIVERTED'])
print(df['DIVERTED'].unique())
# Out:
# 0          False
# 1              F
# 2          False
# 3              0
# 4          False
#            ...
# 1191800        0
# 1191801        F
# 1191802    False
# 1191803        F
# 1191804    False
# Name: DIVERTED, Length: 1191805, dtype: object
# ['False' 'F' '0' '1' 'True' 'T']

# %%
false_mask = df['DIVERTED'].isin(['False', 'F', '0', False])
true_mask = df['DIVERTED'].isin(['True', 'T', '1', True])

df['DIVERTED'][false_mask] = False
df['DIVERTED'][true_mask] = True

df['DIVERTED'] = df['DIVERTED'].astype(bool)

# display(df['DIVERTED'].unique())
display(df[true_mask])
display(df)
# Out:
# /Users/tawfiq/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/tawfiq/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#          TRANSACTIONID  FLIGHTDATE AIRLINECODE  \
# 581            2520700    19920509          WN
# 635           19330500    19950907          WN
# 1065          31896400    19980103          UA
# 1148          21660100    19960118          WN
# 1315          25998800    19960924          WN
# ...                ...         ...         ...
# 1190200      130905600    20130922          EV
# 1190376      133421700    20140102          FL
# 1190378      133667100    20140102          WN
# 1190463      133324600    20140105          EV
# 1190929      128617200    20130518          EV
#
#                              AIRLINENAME TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 581           Southwest Airlines Co.: WN     NaN        945               ABQ
# 635           Southwest Airlines Co.: WN    N343        375               ABQ
# 1065           United Air Lines Inc.: UA  N318UA        574               ABQ
# 1148          Southwest Airlines Co.: WN    N350       1265               ABQ
# 1315          Southwest Airlines Co.: WN     N81        343               ABQ
# ...                                  ...     ...        ...               ...
# 1190200     ExpressJet Airlines Inc.: EV  N760EV       5594               ATL
# 1190376  AirTran Airways Corporation: FL  N278AT       1618               ATL
# 1190378       Southwest Airlines Co.: WN  N656SW        181               ATL
# 1190463     ExpressJet Airlines Inc.: EV  N928EV       5540               ATL
# 1190929     ExpressJet Airlines Inc.: EV  N186PQ       4969               ATL
#
#                                            ORIGAIRPORTNAME ORIGINCITYNAME  \
# 581       AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 635       AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1065      AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1148      AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1315      AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# ...                                                    ...            ...
# 1190200  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1190376  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1190378  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1190463  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1190929  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
#
#         ORIGINSTATE  ... WHEELSON TAXIIN CRSARRTIME ARRTIME ARRDELAY  \
# 581              NM  ...      NaN    NaN       1610     NaN      NaN
# 635              NM  ...      NaN    NaN       2215     NaN      NaN
# 1065             NM  ...      NaN    NaN        846     NaN      NaN
# 1148             NM  ...      NaN    NaN       2220     NaN      NaN
# 1315             NM  ...      NaN    NaN       1230     NaN      NaN
# ...             ...  ...      ...    ...        ...     ...      ...
# 1190200          GA  ...   2303.0    5.0       1917  2308.0      NaN
# 1190376          GA  ...   1155.0   12.0        920  1207.0      NaN
# 1190378          GA  ...      NaN    NaN       1330     NaN      NaN
# 1190463          GA  ...      NaN    NaN       1633     NaN      NaN
# 1190929          GA  ...   1149.0    3.0        945  1152.0      NaN
#
#         CRSELAPSEDTIME  ACTUALELAPSEDTIME  CANCELLED  DIVERTED   DISTANCE
# 581              145.0                NaN          0      True  896 miles
# 635               90.0                NaN          0      True  580 miles
# 1065              71.0                NaN          F      True  349 miles
# 1148             105.0                NaN          F      True  718 miles
# 1315             115.0                NaN          0      True  677 miles
# ...                ...                ...        ...       ...        ...
# 1190200          106.0                NaN          F      True  534 miles
# 1190376          120.0                NaN      False      True  591 miles
# 1190378          120.0                NaN      False      True  591 miles
# 1190463           83.0                NaN      False      True  357 miles
# 1190929          132.0                NaN          0      True  761 miles
#
# [2646 rows x 31 columns]
#          TRANSACTIONID  FLIGHTDATE AIRLINECODE  \
# 0             54548800    20020101          WN
# 1             55872300    20020101          CO
# 2             54388800    20020101          WN
# 3             54486500    20020101          WN
# 4             55878700    20020103          CO
# ...                ...         ...         ...
# 1191800      126750200    20130106          EV
# 1191801      127294500    20130106          DL
# 1191802      127294900    20130106          DL
# 1191803      126594900    20130106          EV
# 1191804      126620300    20130106          EV
#
#                             AIRLINENAME TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 0            Southwest Airlines Co.: WN  N103@@       1425               ABQ
# 1        Continental Air Lines Inc.: CO  N83872        150               ABQ
# 2            Southwest Airlines Co.: WN  N334@@        249               ABQ
# 3            Southwest Airlines Co.: WN  N699@@        902               ABQ
# 4        Continental Air Lines Inc.: CO  N58606        234               ABQ
# ...                                 ...     ...        ...               ...
# 1191800    ExpressJet Airlines Inc.: EV  N683BR       5272               ATL
# 1191801        Delta Air Lines Inc.: DL  N949DL       1711               ATL
# 1191802        Delta Air Lines Inc.: DL  N907DE       1810               ATL
# 1191803    ExpressJet Airlines Inc.: EV  N855AS       5208               ATL
# 1191804    ExpressJet Airlines Inc.: EV  N138EV       5549               ATL
#
#                                            ORIGAIRPORTNAME ORIGINCITYNAME  \
# 0         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 2         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 3         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 4         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# ...                                                    ...            ...
# 1191800  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191801  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191802  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191803  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191804  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
#
#         ORIGINSTATE  ... WHEELSON TAXIIN CRSARRTIME ARRTIME ARRDELAY  \
# 0                NM  ...   1648.0    4.0       1655  1652.0     -3.0
# 1                NM  ...   1419.0   16.0       1426  1435.0      9.0
# 2                NM  ...   1618.0    2.0       1500  1620.0     80.0
# 3                NM  ...   1947.0    1.0       1950  1948.0     -2.0
# 4                NM  ...   1742.0    5.0       1750  1747.0     -3.0
# ...             ...  ...      ...    ...        ...     ...      ...
# 1191800          GA  ...   1500.0    3.0       1523  1503.0    -20.0
# 1191801          GA  ...   2307.0   10.0       2321  2317.0     -4.0
# 1191802          GA  ...   1728.0    9.0       1750  1737.0    -13.0
# 1191803          GA  ...   1651.0    4.0       1658  1655.0     -3.0
# 1191804          GA  ...   1611.0    4.0       1609  1615.0      6.0
#
#         CRSELAPSEDTIME  ACTUALELAPSEDTIME  CANCELLED  DIVERTED   DISTANCE
# 0                 90.0               87.0          F     False  580 miles
# 1                116.0              119.0      False     False  744 miles
# 2                105.0              102.0          F     False  718 miles
# 3                 85.0               83.0          0     False  487 miles
# 4                115.0              114.0          F     False  744 miles
# ...                ...                ...        ...       ...        ...
# 1191800          146.0              135.0          0     False  721 miles
# 1191801          151.0              150.0      False     False  731 miles
# 1191802          153.0              140.0          F     False  731 miles
# 1191803          102.0              101.0      False     False  508 miles
# 1191804           77.0               77.0      False     False  306 miles
#
# [1191805 rows x 31 columns]

# %%
# - find out what’s wrong with the distance column and fix it. Hint: what is the `.sum()` of the distance col?
# display(df['DISTANCE'].str.split(' ').str.get(1).unique()) # check they are all in miles

df['DISTANCE_miles'] = df['DISTANCE'].str.split(' ').str.get(0).astype(int)
display(df['DISTANCE_miles'])
# Out:
# 0          580
# 1          744
# 2          718
# 3          487
# 4          744
#           ...
# 1191800    721
# 1191801    731
# 1191802    731
# 1191803    508
# 1191804    306
# Name: DISTANCE_miles, Length: 1191805, dtype: int64

# %%
# - create a function that uses python’s datetime module to parse the “FLIGHTDATE” 
# to a python datetime object and map that column using the `.apply()` method
# display(df)
from datetime import datetime

df['FLIGHTDATE'] = df['FLIGHTDATE'].astype(str)
df['FLIGHTDATE_datetime'] = df['FLIGHTDATE'].apply(lambda flight_date: datetime.strptime(flight_date, '%Y%m%d'))

display(df)
# Out:
#          TRANSACTIONID FLIGHTDATE AIRLINECODE                     AIRLINENAME  \
# 0             54548800   20020101          WN      Southwest Airlines Co.: WN
# 1             55872300   20020101          CO  Continental Air Lines Inc.: CO
# 2             54388800   20020101          WN      Southwest Airlines Co.: WN
# 3             54486500   20020101          WN      Southwest Airlines Co.: WN
# 4             55878700   20020103          CO  Continental Air Lines Inc.: CO
# ...                ...        ...         ...                             ...
# 1191800      126750200   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191801      127294500   20130106          DL        Delta Air Lines Inc.: DL
# 1191802      127294900   20130106          DL        Delta Air Lines Inc.: DL
# 1191803      126594900   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191804      126620300   20130106          EV    ExpressJet Airlines Inc.: EV
#
#         TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 0        N103@@       1425               ABQ
# 1        N83872        150               ABQ
# 2        N334@@        249               ABQ
# 3        N699@@        902               ABQ
# 4        N58606        234               ABQ
# ...         ...        ...               ...
# 1191800  N683BR       5272               ATL
# 1191801  N949DL       1711               ATL
# 1191802  N907DE       1810               ATL
# 1191803  N855AS       5208               ATL
# 1191804  N138EV       5549               ATL
#
#                                            ORIGAIRPORTNAME ORIGINCITYNAME  \
# 0         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 2         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 3         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 4         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# ...                                                    ...            ...
# 1191800  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191801  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191802  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191803  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191804  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
#
#         ORIGINSTATE  ... CRSARRTIME ARRTIME ARRDELAY CRSELAPSEDTIME  \
# 0                NM  ...       1655  1652.0     -3.0           90.0
# 1                NM  ...       1426  1435.0      9.0          116.0
# 2                NM  ...       1500  1620.0     80.0          105.0
# 3                NM  ...       1950  1948.0     -2.0           85.0
# 4                NM  ...       1750  1747.0     -3.0          115.0
# ...             ...  ...        ...     ...      ...            ...
# 1191800          GA  ...       1523  1503.0    -20.0          146.0
# 1191801          GA  ...       2321  2317.0     -4.0          151.0
# 1191802          GA  ...       1750  1737.0    -13.0          153.0
# 1191803          GA  ...       1658  1655.0     -3.0          102.0
# 1191804          GA  ...       1609  1615.0      6.0           77.0
#
#         ACTUALELAPSEDTIME CANCELLED  DIVERTED   DISTANCE  DISTANCE_miles  \
# 0                    87.0         F     False  580 miles             580
# 1                   119.0     False     False  744 miles             744
# 2                   102.0         F     False  718 miles             718
# 3                    83.0         0     False  487 miles             487
# 4                   114.0         F     False  744 miles             744
# ...                   ...       ...       ...        ...             ...
# 1191800             135.0         0     False  721 miles             721
# 1191801             150.0     False     False  731 miles             731
# 1191802             140.0         F     False  731 miles             731
# 1191803             101.0     False     False  508 miles             508
# 1191804              77.0     False     False  306 miles             306
#
#          FLIGHTDATE_datetime
# 0                 2002-01-01
# 1                 2002-01-01
# 2                 2002-01-01
# 3                 2002-01-01
# 4                 2002-01-03
# ...                      ...
# 1191800           2013-01-06
# 1191801           2013-01-06
# 1191802           2013-01-06
# 1191803           2013-01-06
# 1191804           2013-01-06
#
# [1191805 rows x 33 columns]

# %%
# - now replace that code with `pd.to_datetime()`

from datetime import datetime

# df['FLIGHTDATE'] = df['FLIGHTDATE'].astype(str)
df['FLIGHTDATE_datetime_pd'] = pd.to_datetime(df['FLIGHTDATE'], format='%Y%m%d')

display(df)
# Out:
#          TRANSACTIONID FLIGHTDATE AIRLINECODE                     AIRLINENAME  \
# 0             54548800   20020101          WN      Southwest Airlines Co.: WN
# 1             55872300   20020101          CO  Continental Air Lines Inc.: CO
# 2             54388800   20020101          WN      Southwest Airlines Co.: WN
# 3             54486500   20020101          WN      Southwest Airlines Co.: WN
# 4             55878700   20020103          CO  Continental Air Lines Inc.: CO
# ...                ...        ...         ...                             ...
# 1191800      126750200   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191801      127294500   20130106          DL        Delta Air Lines Inc.: DL
# 1191802      127294900   20130106          DL        Delta Air Lines Inc.: DL
# 1191803      126594900   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191804      126620300   20130106          EV    ExpressJet Airlines Inc.: EV
#
#         TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 0        N103@@       1425               ABQ
# 1        N83872        150               ABQ
# 2        N334@@        249               ABQ
# 3        N699@@        902               ABQ
# 4        N58606        234               ABQ
# ...         ...        ...               ...
# 1191800  N683BR       5272               ATL
# 1191801  N949DL       1711               ATL
# 1191802  N907DE       1810               ATL
# 1191803  N855AS       5208               ATL
# 1191804  N138EV       5549               ATL
#
#                                            ORIGAIRPORTNAME ORIGINCITYNAME  \
# 0         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 2         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 3         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 4         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# ...                                                    ...            ...
# 1191800  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191801  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191802  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191803  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191804  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
#
#         ORIGINSTATE  ... ARRTIME ARRDELAY CRSELAPSEDTIME ACTUALELAPSEDTIME  \
# 0                NM  ...  1652.0     -3.0           90.0              87.0
# 1                NM  ...  1435.0      9.0          116.0             119.0
# 2                NM  ...  1620.0     80.0          105.0             102.0
# 3                NM  ...  1948.0     -2.0           85.0              83.0
# 4                NM  ...  1747.0     -3.0          115.0             114.0
# ...             ...  ...     ...      ...            ...               ...
# 1191800          GA  ...  1503.0    -20.0          146.0             135.0
# 1191801          GA  ...  2317.0     -4.0          151.0             150.0
# 1191802          GA  ...  1737.0    -13.0          153.0             140.0
# 1191803          GA  ...  1655.0     -3.0          102.0             101.0
# 1191804          GA  ...  1615.0      6.0           77.0              77.0
#
#         CANCELLED DIVERTED   DISTANCE  DISTANCE_miles  FLIGHTDATE_datetime  \
# 0               F    False  580 miles             580           2002-01-01
# 1           False    False  744 miles             744           2002-01-01
# 2               F    False  718 miles             718           2002-01-01
# 3               0    False  487 miles             487           2002-01-01
# 4               F    False  744 miles             744           2002-01-03
# ...           ...      ...        ...             ...                  ...
# 1191800         0    False  721 miles             721           2013-01-06
# 1191801     False    False  731 miles             731           2013-01-06
# 1191802         F    False  731 miles             731           2013-01-06
# 1191803     False    False  508 miles             508           2013-01-06
# 1191804     False    False  306 miles             306           2013-01-06
#
#          FLIGHTDATE_datetime_pd
# 0                    2002-01-01
# 1                    2002-01-01
# 2                    2002-01-01
# 3                    2002-01-01
# 4                    2002-01-03
# ...                         ...
# 1191800              2013-01-06
# 1191801              2013-01-06
# 1191802              2013-01-06
# 1191803              2013-01-06
# 1191804              2013-01-06
#
# [1191805 rows x 34 columns]

# %%
   # - use the `.duplicated()` method to count how many exact duplicates there are in the dataset
duplicated = df.duplicated(keep='last')
display(df[duplicated])

# No duplicates found?
# Out:
# Empty DataFrame
# Columns: [TRANSACTIONID, FLIGHTDATE, AIRLINECODE, AIRLINENAME, TAILNUM, FLIGHTNUM, ORIGINAIRPORTCODE, ORIGAIRPORTNAME, ORIGINCITYNAME, ORIGINSTATE, ORIGINSTATENAME, DESTAIRPORTCODE, DESTAIRPORTNAME, DESTCITYNAME, DESTSTATE, DESTSTATENAME, CRSDEPTIME, DEPTIME, DEPDELAY, TAXIOUT, WHEELSOFF, WHEELSON, TAXIIN, CRSARRTIME, ARRTIME, ARRDELAY, CRSELAPSEDTIME, ACTUALELAPSEDTIME, CANCELLED, DIVERTED, DISTANCE, DISTANCE_miles, FLIGHTDATE_datetime, FLIGHTDATE_datetime_pd]
# Index: []
#
# [0 rows x 34 columns]

# %%
# - we might want to remove rows that are not exact duplicates, 
#  but are duplicates across some subset of columns. 
# For example, if we have duplicate users in a table 
#  with the same user_id, but maybe different bios, they should probably be marked as duplicate. 

# Use the `subset` kwarg in the `.duplicated()` method 
#  to check for entries that are matched exactly at the following columns

       # - `“ORIGAIRPORTNAME”, “DESTAIRPORTNAME”, “AIRLINECODE”, “FLIGHTDATE”, “CRSDEPTIME”, “DEPTIME”, “ARRTIME”`
duplicate_columns_to_check = ["ORIGAIRPORTNAME", "DESTAIRPORTNAME", "AIRLINECODE", "FLIGHTDATE", "CRSDEPTIME", "DEPTIME", "ARRTIME"]
duplicated = df.duplicated(subset=duplicate_columns_to_check)

display(df[duplicated])
# Out:
#          TRANSACTIONID FLIGHTDATE AIRLINECODE                 AIRLINENAME  \
# 125015        22097200   19960118          AA  American Airlines Inc.: AA
# 162445        27453500   19970113          AA  American Airlines Inc.: AA
# 377882        21910200   19960107          AA  American Airlines Inc.: AA
# 453974         1977500   19920528          AS    Alaska Airlines Inc.: AS
# 603813        21097100   19960108          AA  American Airlines Inc.: AA
# 760553        32274400   19980108          AA  American Airlines Inc.: AA
# 769567        22394500   19960107          AA  American Airlines Inc.: AA
# 810576        21756100   19960108          AA  American Airlines Inc.: AA
# 1174656       31977700   19980106          AA  American Airlines Inc.: AA
# 1175821       20838000   19960108          AA  American Airlines Inc.: AA
# 1175879       21808800   19960111          AA  American Airlines Inc.: AA
# 1185114       27174500   19970126          AA  American Airlines Inc.: AA
#
#         TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 125015   UNKNOW       1988               MCI
# 162445   UNKNOW       2056               IAH
# 377882   UNKNOW       1009               DCA
# 453974      NaN        118               ANC
# 603813   UNKNOW       1684               DFW
# 760553   UNKNOW       2098               LAX
# 769567   UNKNOW          2               LAX
# 810576   UNKNOW       1485               LGA
# 1174656  UNKNOW        378               ORD
# 1175821  UNKNOW       1920               ORD
# 1175879  UNKNOW       1995               ORD
# 1185114  UNKNOW       1140               ORD
#
#                                            ORIGAIRPORTNAME     ORIGINCITYNAME  \
# 125015            Kansas CityMO: Kansas City International        Kansas City
# 162445     HoustonTX: George Bush Intercontinental/Houston            Houston
# 377882     WashingtonDC: Ronald Reagan Washington National         Washington
# 453974    AnchorageAK: Ted Stevens Anchorage International          Anchorage
# 603813   Dallas/Fort WorthTX: Dallas/Fort Worth Interna...  Dallas/Fort Worth
# 760553            Los AngelesCA: Los Angeles International        Los Angeles
# 769567            Los AngelesCA: Los Angeles International        Los Angeles
# 810576                               New YorkNY: LaGuardia           New York
# 1174656            ChicagoIL: Chicago O'Hare International            Chicago
# 1175821            ChicagoIL: Chicago O'Hare International            Chicago
# 1175879            ChicagoIL: Chicago O'Hare International            Chicago
# 1185114            ChicagoIL: Chicago O'Hare International            Chicago
#
#         ORIGINSTATE  ... ARRTIME ARRDELAY CRSELAPSEDTIME ACTUALELAPSEDTIME  \
# 125015           MO  ...     NaN      NaN            NaN               NaN
# 162445           TX  ...     NaN      NaN            NaN               NaN
# 377882           VA  ...     NaN      NaN            NaN               NaN
# 453974           AK  ...  1405.0     -5.0          200.0             195.0
# 603813           TX  ...     NaN      NaN            NaN               NaN
# 760553           CA  ...     NaN      NaN            NaN               NaN
# 769567           CA  ...     NaN      NaN            NaN               NaN
# 810576           NY  ...     NaN      NaN            NaN               NaN
# 1174656          IL  ...     NaN      NaN            NaN               NaN
# 1175821          IL  ...     NaN      NaN            NaN               NaN
# 1175879          IL  ...     NaN      NaN            NaN               NaN
# 1185114          IL  ...     NaN      NaN            NaN               NaN
#
#         CANCELLED DIVERTED    DISTANCE  DISTANCE_miles  FLIGHTDATE_datetime  \
# 125015       True    False   460 miles             460           1996-01-18
# 162445       True    False   224 miles             224           1997-01-13
# 377882       True    False   612 miles             612           1996-01-07
# 453974      False    False  1448 miles            1448           1992-05-28
# 603813       True    False  1192 miles            1192           1996-01-08
# 760553       True    False  1745 miles            1745           1998-01-08
# 769567       True    False  2475 miles            2475           1996-01-07
# 810576       True    False  1097 miles            1097           1996-01-08
# 1174656      True    False   733 miles             733           1998-01-06
# 1175821      True    False   783 miles             783           1996-01-08
# 1175879      True    False   334 miles             334           1996-01-11
# 1185114      True    False   334 miles             334           1997-01-26
#
#          FLIGHTDATE_datetime_pd
# 125015               1996-01-18
# 162445               1997-01-13
# 377882               1996-01-07
# 453974               1992-05-28
# 603813               1996-01-08
# 760553               1998-01-08
# 769567               1996-01-07
# 810576               1996-01-08
# 1174656              1998-01-06
# 1175821              1996-01-08
# 1175879              1996-01-11
# 1185114              1997-01-26
#
# [12 rows x 34 columns]

# %%
# - what are the different values for the `keep` kwarg? What do they do? Which do you want to use here?
# - look up how to use the `.sort_values()` method and sort the dataframe

duplicate_columns_to_check = ["ORIGAIRPORTNAME", "DESTAIRPORTNAME", "AIRLINECODE", "FLIGHTDATE", "CRSDEPTIME", "DEPTIME", "ARRTIME"]
# duplicated = df.duplicated(subset=duplicate_columns_to_check, keep=False)
# display(df[duplicated][duplicate_columns_to_check].sort_values(['FLIGHTDATE','ORIGAIRPORTNAME']))

# - use the `.drop_duplicates()` method to remove the duplicates
df_duplicates_removed = df.drop_duplicates(subset=duplicate_columns_to_check)

display(df)
display(df_duplicates_removed)
# Out:
#                                            ORIGAIRPORTNAME  \
# 34300     AnchorageAK: Ted Stevens Anchorage International
# 453974    AnchorageAK: Ted Stevens Anchorage International
# 769566            Los AngelesCA: Los Angeles International
# 769567            Los AngelesCA: Los Angeles International
# 377880     WashingtonDC: Ronald Reagan Washington National
# 377882     WashingtonDC: Ronald Reagan Washington National
# 585779             ChicagoIL: Chicago O'Hare International
# 1175821            ChicagoIL: Chicago O'Hare International
# 603812   Dallas/Fort WorthTX: Dallas/Fort Worth Interna...
# 603813   Dallas/Fort WorthTX: Dallas/Fort Worth Interna...
# 192865                               New YorkNY: LaGuardia
# 810576                               New YorkNY: LaGuardia
# 585484             ChicagoIL: Chicago O'Hare International
# 1175879            ChicagoIL: Chicago O'Hare International
# 125014            Kansas CityMO: Kansas City International
# 125015            Kansas CityMO: Kansas City International
# 162444     HoustonTX: George Bush Intercontinental/Houston
# 162445     HoustonTX: George Bush Intercontinental/Houston
# 583756             ChicagoIL: Chicago O'Hare International
# 1185114            ChicagoIL: Chicago O'Hare International
# 1174655            ChicagoIL: Chicago O'Hare International
# 1174656            ChicagoIL: Chicago O'Hare International
# 103931            Los AngelesCA: Los Angeles International
# 760553            Los AngelesCA: Los Angeles International
#
#                                            DESTAIRPORTNAME AIRLINECODE  \
# 34300              SeattleWA: Seattle/Tacoma International          AS
# 453974             SeattleWA: Seattle/Tacoma International          AS
# 769566           New YorkNY: John F. Kennedy International          AA
# 769567           New YorkNY: John F. Kennedy International          AA
# 377880             ChicagoIL: Chicago O'Hare International          AA
# 377882             ChicagoIL: Chicago O'Hare International          AA
# 585779                   HartfordCT: Bradley International          AA
# 1175821                  HartfordCT: Bradley International          AA
# 603812     WashingtonDC: Ronald Reagan Washington National          AA
# 603813     WashingtonDC: Ronald Reagan Washington National          AA
# 192865                        MiamiFL: Miami International          AA
# 810576                        MiamiFL: Miami International          AA
# 585484    MinneapolisMN: Minneapolis-St Paul International          AA
# 1175879   MinneapolisMN: Minneapolis-St Paul International          AA
# 125014   Dallas/Fort WorthTX: Dallas/Fort Worth Interna...          AA
# 125015   Dallas/Fort WorthTX: Dallas/Fort Worth Interna...          AA
# 162444   Dallas/Fort WorthTX: Dallas/Fort Worth Interna...          AA
# 162445   Dallas/Fort WorthTX: Dallas/Fort Worth Interna...          AA
# 583756    MinneapolisMN: Minneapolis-St Paul International          AA
# 1185114   MinneapolisMN: Minneapolis-St Paul International          AA
# 1174655                              New YorkNY: LaGuardia          AA
# 1174656                              New YorkNY: LaGuardia          AA
# 103931             ChicagoIL: Chicago O'Hare International          AA
# 760553             ChicagoIL: Chicago O'Hare International          AA
#
#         FLIGHTDATE  CRSDEPTIME  DEPTIME  ARRTIME
# 34300     19920528         950    950.0   1405.0
# 453974    19920528         950    950.0   1405.0
# 769566    19960107           0      NaN      NaN
# 769567    19960107           0      NaN      NaN
# 377880    19960107           0      NaN      NaN
# 377882    19960107           0      NaN      NaN
# 585779    19960108           0      NaN      NaN
# 1175821   19960108           0      NaN      NaN
# 603812    19960108           0      NaN      NaN
# 603813    19960108           0      NaN      NaN
# 192865    19960108           0      NaN      NaN
# 810576    19960108           0      NaN      NaN
# 585484    19960111           0      NaN      NaN
# 1175879   19960111           0      NaN      NaN
# 125014    19960118           0      NaN      NaN
# 125015    19960118           0      NaN      NaN
# 162444    19970113           0      NaN      NaN
# 162445    19970113           0      NaN      NaN
# 583756    19970126           0      NaN      NaN
# 1185114   19970126           0      NaN      NaN
# 1174655   19980106           0      NaN      NaN
# 1174656   19980106           0      NaN      NaN
# 103931    19980108           0      NaN      NaN
# 760553    19980108           0      NaN      NaN
#          TRANSACTIONID FLIGHTDATE AIRLINECODE                     AIRLINENAME  \
# 0             54548800   20020101          WN      Southwest Airlines Co.: WN
# 1             55872300   20020101          CO  Continental Air Lines Inc.: CO
# 2             54388800   20020101          WN      Southwest Airlines Co.: WN
# 3             54486500   20020101          WN      Southwest Airlines Co.: WN
# 4             55878700   20020103          CO  Continental Air Lines Inc.: CO
# ...                ...        ...         ...                             ...
# 1191800      126750200   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191801      127294500   20130106          DL        Delta Air Lines Inc.: DL
# 1191802      127294900   20130106          DL        Delta Air Lines Inc.: DL
# 1191803      126594900   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191804      126620300   20130106          EV    ExpressJet Airlines Inc.: EV
#
#         TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 0        N103@@       1425               ABQ
# 1        N83872        150               ABQ
# 2        N334@@        249               ABQ
# 3        N699@@        902               ABQ
# 4        N58606        234               ABQ
# ...         ...        ...               ...
# 1191800  N683BR       5272               ATL
# 1191801  N949DL       1711               ATL
# 1191802  N907DE       1810               ATL
# 1191803  N855AS       5208               ATL
# 1191804  N138EV       5549               ATL
#
#                                            ORIGAIRPORTNAME ORIGINCITYNAME  \
# 0         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 2         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 3         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 4         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# ...                                                    ...            ...
# 1191800  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191801  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191802  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191803  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191804  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
#
#         ORIGINSTATE  ... ARRTIME ARRDELAY CRSELAPSEDTIME ACTUALELAPSEDTIME  \
# 0                NM  ...  1652.0     -3.0           90.0              87.0
# 1                NM  ...  1435.0      9.0          116.0             119.0
# 2                NM  ...  1620.0     80.0          105.0             102.0
# 3                NM  ...  1948.0     -2.0           85.0              83.0
# 4                NM  ...  1747.0     -3.0          115.0             114.0
# ...             ...  ...     ...      ...            ...               ...
# 1191800          GA  ...  1503.0    -20.0          146.0             135.0
# 1191801          GA  ...  2317.0     -4.0          151.0             150.0
# 1191802          GA  ...  1737.0    -13.0          153.0             140.0
# 1191803          GA  ...  1655.0     -3.0          102.0             101.0
# 1191804          GA  ...  1615.0      6.0           77.0              77.0
#
#         CANCELLED DIVERTED   DISTANCE  DISTANCE_miles  FLIGHTDATE_datetime  \
# 0               F    False  580 miles             580           2002-01-01
# 1           False    False  744 miles             744           2002-01-01
# 2               F    False  718 miles             718           2002-01-01
# 3               0    False  487 miles             487           2002-01-01
# 4               F    False  744 miles             744           2002-01-03
# ...           ...      ...        ...             ...                  ...
# 1191800         0    False  721 miles             721           2013-01-06
# 1191801     False    False  731 miles             731           2013-01-06
# 1191802         F    False  731 miles             731           2013-01-06
# 1191803     False    False  508 miles             508           2013-01-06
# 1191804     False    False  306 miles             306           2013-01-06
#
#          FLIGHTDATE_datetime_pd
# 0                    2002-01-01
# 1                    2002-01-01
# 2                    2002-01-01
# 3                    2002-01-01
# 4                    2002-01-03
# ...                         ...
# 1191800              2013-01-06
# 1191801              2013-01-06
# 1191802              2013-01-06
# 1191803              2013-01-06
# 1191804              2013-01-06
#
# [1191805 rows x 34 columns]
#          TRANSACTIONID FLIGHTDATE AIRLINECODE                     AIRLINENAME  \
# 0             54548800   20020101          WN      Southwest Airlines Co.: WN
# 1             55872300   20020101          CO  Continental Air Lines Inc.: CO
# 2             54388800   20020101          WN      Southwest Airlines Co.: WN
# 3             54486500   20020101          WN      Southwest Airlines Co.: WN
# 4             55878700   20020103          CO  Continental Air Lines Inc.: CO
# ...                ...        ...         ...                             ...
# 1191800      126750200   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191801      127294500   20130106          DL        Delta Air Lines Inc.: DL
# 1191802      127294900   20130106          DL        Delta Air Lines Inc.: DL
# 1191803      126594900   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191804      126620300   20130106          EV    ExpressJet Airlines Inc.: EV
#
#         TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 0        N103@@       1425               ABQ
# 1        N83872        150               ABQ
# 2        N334@@        249               ABQ
# 3        N699@@        902               ABQ
# 4        N58606        234               ABQ
# ...         ...        ...               ...
# 1191800  N683BR       5272               ATL
# 1191801  N949DL       1711               ATL
# 1191802  N907DE       1810               ATL
# 1191803  N855AS       5208               ATL
# 1191804  N138EV       5549               ATL
#
#                                            ORIGAIRPORTNAME ORIGINCITYNAME  \
# 0         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 2         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 3         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 4         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# ...                                                    ...            ...
# 1191800  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191801  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191802  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191803  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191804  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
#
#         ORIGINSTATE  ... ARRTIME ARRDELAY CRSELAPSEDTIME ACTUALELAPSEDTIME  \
# 0                NM  ...  1652.0     -3.0           90.0              87.0
# 1                NM  ...  1435.0      9.0          116.0             119.0
# 2                NM  ...  1620.0     80.0          105.0             102.0
# 3                NM  ...  1948.0     -2.0           85.0              83.0
# 4                NM  ...  1747.0     -3.0          115.0             114.0
# ...             ...  ...     ...      ...            ...               ...
# 1191800          GA  ...  1503.0    -20.0          146.0             135.0
# 1191801          GA  ...  2317.0     -4.0          151.0             150.0
# 1191802          GA  ...  1737.0    -13.0          153.0             140.0
# 1191803          GA  ...  1655.0     -3.0          102.0             101.0
# 1191804          GA  ...  1615.0      6.0           77.0              77.0
#
#         CANCELLED DIVERTED   DISTANCE  DISTANCE_miles  FLIGHTDATE_datetime  \
# 0               F    False  580 miles             580           2002-01-01
# 1           False    False  744 miles             744           2002-01-01
# 2               F    False  718 miles             718           2002-01-01
# 3               0    False  487 miles             487           2002-01-01
# 4               F    False  744 miles             744           2002-01-03
# ...           ...      ...        ...             ...                  ...
# 1191800         0    False  721 miles             721           2013-01-06
# 1191801     False    False  731 miles             731           2013-01-06
# 1191802         F    False  731 miles             731           2013-01-06
# 1191803     False    False  508 miles             508           2013-01-06
# 1191804     False    False  306 miles             306           2013-01-06
#
#          FLIGHTDATE_datetime_pd
# 0                    2002-01-01
# 1                    2002-01-01
# 2                    2002-01-01
# 3                    2002-01-01
# 4                    2002-01-03
# ...                         ...
# 1191800              2013-01-06
# 1191801              2013-01-06
# 1191802              2013-01-06
# 1191803              2013-01-06
# 1191804              2013-01-06
#
# [1191793 rows x 34 columns]

# %%
# - look up how to use the `.unique()` method and check the ‘TAILNUM’ column. 
# Notice anything that shouldn’t be there?
display(df['TAILNUM'])
print(list(df['TAILNUM'].unique()) )
display(df_duplicates_removed)

# - replace
# Out:
# 0          N103@@
# 1          N83872
# 2          N334@@
# 3          N699@@
# 4          N58606
#             ...
# 1191800    N683BR
# 1191801    N949DL
# 1191802    N907DE
# 1191803    N855AS
# 1191804    N138EV
# Name: TAILNUM, Length: 1191805, dtype: object
# ['N103@@', 'N83872', 'N334@@', 'N699@@', 'N58606', 'N501@@', 'N37574', 'N517D1', 'N679@@', 'N791@@', 'N662@@', 'N330@@', 'N328@@', 'N507@@', 'N773@@', 'N602@@', 'N17326', 'N316A', 'N87@@@', 'N326@@', 'N4HA1', 'N745@@', 'N695@@', 'N331@@', 'N313@@', 'N168A', 'N644@@', 'N361@@', 'N634@@', 'N9361', 'N382@@', 'N300@@', 'N635@@', 'N14384', 'N314A', 'N96@@@', 'N729@@', 'N308A', 'N9491', 'N760@@', 'N312', 'N385@@', 'N343@@', 'N615@@', 'N3891', 'N307', 'N603@@', 'N375@@', 'N4BA1', 'N3731', 'N607@@', 'N653@@', 'N511@@', 'N2931', 'N3411', 'N740@@', 'N14308', 'N678', 'N647', 'N334AW', 'N640', 'N37700', 'N700', 'N69333', 'N326', 'N683', 'N718', 'N326US', 'N373NW', 'N822MQ', 'N913UA', 'N722', 'N330', 'N687', 'N340', 'N728', 'N508', 'N617', 'N643AW', 'N526AA', 'N730', 'N682', 'N4WWAA', 'N753', 'N725', 'N361', 'N685', 'N105', 'N521AA', 'N523', 'N504', 'N81', 'N528', 'N373UA', 'N634', 'N641', 'N4TTAA', 'N342', 'N584AA', 'N311', 'N760', 'N388', 'N412AA', 'N354', 'N4XYAA', 'N375DA', 'N150AW', 'N345', 'N627', 'N686@@', 'N27610', 'N624@@', 'N104@@', 'N311@@', 'N931', 'N332@@', 'N360@@', 'N786@@', 'N750@@', 'N165A', 'N335A', 'N322A', 'N643@@', 'N673@@', 'N3081', 'N17328', 'N743@@', 'N640@@', 'N709@@', 'N315@@', 'N479A1', 'N736@@', 'N902', 'N323@@', 'N73380', 'N527@@', 'N9406', 'N486A1', 'N656@@', 'N576A1', 'N565A1', 'N346@@', 'N757@@', 'N373D1', 'N9391', 'N534A1', 'N655@@', 'N321@@', 'N628@@', 'N926', 'N3071', 'N345@@', 'N622@@', 'N363@@', 'N7459', 'N319', 'N2816', 'N939A', 'N55', 'N699', 'N614', 'N703', 'N2810W', 'N612', 'N671', 'N969DL', 'N489DA', 'N469AA', 'N255AA', 'N936DL', 'N343', 'N330AW', 'N363', 'N155AW', 'N245WA', 'N674', 'N602', 'N301', 'N974UA', 'N503', 'N965DL', 'N387', 'N9402W', 'N7264U', 'N526', 'N938DL', 'N82', 'N375', 'N942DL', 'N710', 'N33635', 'N349', 'N711', 'N169AW', 'N587AA', 'N991UA', 'N651', 'N607', 'N372', 'N654', 'N722RW', 'N16632', 'N329AW', 'N982DL', 'N609', 'N610', 'N512AA', 'N376', 'N341', 'N605', 'N515DA', 'N719RC', 'N129', 'N639', 'N378', 'N300', 'N650', 'N7253U', 'N348', 'N805EA', 'N228AA', 'N690', 'N302UA', 'N283WA', 'N94', 'N309AW', 'N633', 'N910A', 'N366@@', 'N291A1', 'N3531', 'N776@@', 'N609@@', 'N674@@', 'N307A', 'N708@@', 'N659@@', 'N2941', 'N691@@', 'N5911', 'N729R', 'N396@@', 'N737@@', 'N774@@', 'N538D1', 'N2829', 'N798@@', 'N356@@', 'N522D1', 'N130@@', 'N313A', 'N682@@', 'N14839', 'N74@@@', 'N713@@', 'N271A1', 'N83@@@', 'N514@@', 'N287', 'N3471', 'N16642', 'N920', 'N390@@', 'N601@@', 'N7464', 'N344@@', 'N9306', 'N275A1', 'N613@@', 'EI`B4', 'N783@@', 'N509@@', 'N625A', 'N328A', 'N478A3', 'N302@@', 'N504@@', 'N684@@', 'N7258', 'N14889', 'N339@@', 'N226AA', 'N323UA', 'N308AW', 'N697', 'N74', 'N306', 'N17316', 'N652', 'N382', 'N336AW', 'N724', 'N7270U', 'N432AA', 'N516AA', 'N696', 'N334', 'N13891', 'N903TW', 'N626', 'N383', 'N630', 'N392', 'N365', 'N7289U', 'N976TW', 'N337', 'N73', 'N831L', 'N395', 'N673', 'N308', 'N911TW', 'N7261U', 'N336', 'N668', 'N232DZ', 'N604', 'N528DA', 'N338UA', 'N611', 'N655AW', 'N658', 'N158AW', 'N720', 'N541UA', 'N511', 'N14653', 'N60', 'N921DL', 'N513UA', 'N331', 'UNKNOW', 'N512', 'N636', 'N689', 'N517AA', 'N629', 'N649', 'N546DA', 'N71', 'N613', 'N164AW', 'N458AA', 'N364', 'N316UA', 'N538DA', 'N335', 'N310', 'N940AS', 'N7441U', 'N7259U', 'N353', 'N642', 'N384', 'N648', 'N915AW', 'N908TW', 'N935DL', 'N739', 'N320', 'N312WA', 'N149AW', 'N174AW', 'N924DL', 'N655', 'N9401W', 'N920DL', 'N91', 'N322UA', 'N663', 'N396', 'N521UA', 'N675', 'N793@@', 'N600@@', 'N402@@', 'N391@@', 'N286A1', 'N535D1', 'N375D1', 'N685@@', 'N164A', 'N394@@', 'N717@@', 'N955@', 'N525D1', 'N305@@', 'N746@@', 'N778@@', 'NKNO', 'N627@@', 'N612@@', 'N715@@', 'N306@@', 'N16807', 'N415A1', 'N351N', 'N302A', 'N693@@', 'N7299', 'N17730', 'N719@@', 'N9071', 'N619@@', 'N401@@', 'N638@@', 'N378@@', 'N355@@', 'N669@@', 'N625@@', 'N701@@', '-N948', 'N98876', 'N936A', 'N546A1', 'N7460', 'N909', 'N779@@', 'N24729', 'N974TW', 'N573AA', 'N535AA', 'N501', 'N623', 'N918TW', 'N7448U', 'N514', 'N386', 'N2816W', 'N343UA', 'N366', 'N4 ...
#          TRANSACTIONID FLIGHTDATE AIRLINECODE                     AIRLINENAME  \
# 0             54548800   20020101          WN      Southwest Airlines Co.: WN
# 1             55872300   20020101          CO  Continental Air Lines Inc.: CO
# 2             54388800   20020101          WN      Southwest Airlines Co.: WN
# 3             54486500   20020101          WN      Southwest Airlines Co.: WN
# 4             55878700   20020103          CO  Continental Air Lines Inc.: CO
# ...                ...        ...         ...                             ...
# 1191800      126750200   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191801      127294500   20130106          DL        Delta Air Lines Inc.: DL
# 1191802      127294900   20130106          DL        Delta Air Lines Inc.: DL
# 1191803      126594900   20130106          EV    ExpressJet Airlines Inc.: EV
# 1191804      126620300   20130106          EV    ExpressJet Airlines Inc.: EV
#
#         TAILNUM  FLIGHTNUM ORIGINAIRPORTCODE  \
# 0        N103@@       1425               ABQ
# 1        N83872        150               ABQ
# 2        N334@@        249               ABQ
# 3        N699@@        902               ABQ
# 4        N58606        234               ABQ
# ...         ...        ...               ...
# 1191800  N683BR       5272               ATL
# 1191801  N949DL       1711               ATL
# 1191802  N907DE       1810               ATL
# 1191803  N855AS       5208               ATL
# 1191804  N138EV       5549               ATL
#
#                                            ORIGAIRPORTNAME ORIGINCITYNAME  \
# 0         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 1         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 2         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 3         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# 4         AlbuquerqueNM: Albuquerque International Sunport    Albuquerque
# ...                                                    ...            ...
# 1191800  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191801  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191802  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191803  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
# 1191804  AtlantaGA: Hartsfield-Jackson Atlanta Internat...        Atlanta
#
#         ORIGINSTATE  ... ARRTIME ARRDELAY CRSELAPSEDTIME ACTUALELAPSEDTIME  \
# 0                NM  ...  1652.0     -3.0           90.0              87.0
# 1                NM  ...  1435.0      9.0          116.0             119.0
# 2                NM  ...  1620.0     80.0          105.0             102.0
# 3                NM  ...  1948.0     -2.0           85.0              83.0
# 4                NM  ...  1747.0     -3.0          115.0             114.0
# ...             ...  ...     ...      ...            ...               ...
# 1191800          GA  ...  1503.0    -20.0          146.0             135.0
# 1191801          GA  ...  2317.0     -4.0          151.0             150.0
# 1191802          GA  ...  1737.0    -13.0          153.0             140.0
# 1191803          GA  ...  1655.0     -3.0          102.0             101.0
# 1191804          GA  ...  1615.0      6.0           77.0              77.0
#
#         CANCELLED DIVERTED   DISTANCE  DISTANCE_miles  FLIGHTDATE_datetime  \
# 0               F    False  580 miles             580           2002-01-01
# 1           False    False  744 miles             744           2002-01-01
# 2               F    False  718 miles             718           2002-01-01
# 3               0    False  487 miles             487           2002-01-01
# 4               F    False  744 miles             744           2002-01-03
# ...           ...      ...        ...             ...                  ...
# 1191800         0    False  721 miles             721           2013-01-06
# 1191801     False    False  731 miles             731           2013-01-06
# 1191802         F    False  731 miles             731           2013-01-06
# 1191803     False    False  508 miles             508           2013-01-06
# 1191804     False    False  306 miles             306           2013-01-06
#
#          FLIGHTDATE_datetime_pd
# 0                    2002-01-01
# 1                    2002-01-01
# 2                    2002-01-01
# 3                    2002-01-01
# 4                    2002-01-03
# ...                         ...
# 1191800              2013-01-06
# 1191801              2013-01-06
# 1191802              2013-01-06
# 1191803              2013-01-06
# 1191804              2013-01-06
#
# [1191793 rows x 34 columns]

# %%
# - use the `.value_counts()` method to count the different values in the “CANCELLED” column. There is definitely something wrong. Check out the `.replace()` method and fix it. What are the types of arguments that `.replace()` can take in?
# - where appropriate, convert numerical columns into categories
